# %%
import PyPDF2 as p2
import pandas as pd
import tabula
# https://www.cdfa.ca.gov/statistics/PDFs/2018-2019AgReportnass.pdf
 
# tables = tabula.read_pdf(file, pages = "all", multiple_tables = True)

# %%
file=open('CommodityHarvested2018.pdf','rb' )

# %%
tables = tabula.read_pdf(file, pages = "1", multiple_tables = True)
# Out:
# Error from tabula-java:
# Error: Error: Header doesn't contain versioninfo
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-26-b000cb95d5e1> in <module>
# ----> 1 tables = tabula.read_pdf(file, pages = "1", multiple_tables = True)
#
# ~\anaconda3\lib\site-packages\tabula\io.py in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, **kwargs)
#     320
#     321     try:
# --> 322         output = _run(java_options, kwargs, path, encoding)
#     323     finally:
#     324         if temporary:
#
# ~\anaconda3\lib\site-packages\tabula\io.py in _run(java_options, options, path, encoding)
#      83             stderr=subprocess.PIPE,
#      84             stdin=subprocess.DEVNULL,
# ---> 85             check=True,
#      86         )
#      87         if result.stderr:
#
# ...

# %%
! PATH
# Out:
# PATH=C:\Program Files (x86)\Common Files\Oracle\Java\javapath;C:\Windows\system32;C:\Windows;C:\Windows\System32\Wbem;C:\Windows\System32\WindowsPowerShell\v1.0\;C:\Windows\System32\OpenSSH\;C:\Program Files (x86)\Java\jre1.8.0_261\bin;C:\Users\bruno\anaconda3;C:\Users\bruno\anaconda3\Library\mingw-w64\bin;C:\Users\bruno\anaconda3\Library\usr\bin;C:\Users\bruno\anaconda3\Library\bin;C:\Users\bruno\anaconda3\Scripts;C:\Users\bruno\AppData\Local\Microsoft\WindowsApps;C:\Users\bruno\AppData\Local\Programs\Azure Data Studio\bin;C:\Users\bruno\AppData\Local\atom\bin;C:\Program Files (x86)\Java\jre1.8.0_261\bin;

# %%
pdfread=p2.PdfFileReader(file)

# %%
i=0
while i<pdfread.getNumPages():
    pageinfo=pdfread.getPage(i)
    print(pageinfo.extractText())
    i=i+1

# %%
x=pdfread.getPage(2)

# %%
x
# df=x.extractText()
# Out:
# {'/Contents': {'/Filter': '/FlateDecode'},
#  '/CropBox': [0, 0, 612, 792],
#  '/MediaBox': [0, 0, 612, 792],
#  '/Parent': {'/Count': 6,
#   '/Kids': [IndirectObject(5576, 0),
#    IndirectObject(1, 0),
#    IndirectObject(6, 0),
#    IndirectObject(10, 0),
#    IndirectObject(14, 0),
#    IndirectObject(18, 0)],
#   '/Type': '/Pages'},
#  '/Resources': {'/ExtGState': {'/GS0': {'/OP': <PyPDF2.generic.BooleanObject at 0x1e79ff79888>,
#     '/OPM': 1,
#     '/SA': <PyPDF2.generic.BooleanObject at 0x1e79ff994c8>,
#     '/SM': 0.02,
#     '/Type': '/ExtGState',
#     '/op': <PyPDF2.generic.BooleanObject at 0x1e7a0000e88>}},
#   '/Font': {'/C2_0': {'/BaseFont': '/BFLCDG+Arial-BoldMT',
#     '/DescendantFonts': [IndirectObject(5601, 0)],
#     '/Encoding': '/Identity-H',
#     '/Subtype': '/Type0',
#     '/ToUnicode': {'/Filter': '/FlateDecode'},
#     '/Type': '/Font'},
#    '/C2_1': {'/BaseFont': '/BFLCFH+ArialMT',
#     '/DescendantFonts': [IndirectObject(5607, 0)],
# ...

# %%
df=tables[0]

# %%
df=pd.DataFrame(tables)

# %%
df.head()
# Out:
#                                                    0
# 0                                                ...
# 1        Fresno     Glenn  Humboldt  Imperial   I...
# 2         Marin  Mariposa  Mendocino    Merced   ...
# 3       Plumas  Riverside  Sacramento  San Benito...
# 4      Santa Cruz  Shasta  Sierra   Siskiyou   So...
