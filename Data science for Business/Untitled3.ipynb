# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, normalize

# %%
df=pd.read_csv('waternelon result.csv')

# %%
df.head()
# Out:
#                                     _id originName totalWeightSum  \
# 0  ObjectId("5f0fcf208b390b44eccabe6f")     MEXICO         216436
# 1  ObjectId("5f0fcf208b390b44eccabe6e")     MEXICO         506022
# 2  ObjectId("5f0fcf208b390b44eccabe6d")     MEXICO          40139
# 3  ObjectId("5f0fcf208b390b44eccabe6c")     MEXICO          92059
# 4  ObjectId("5f0fcf1e8b390b44eccabc26")     MEXICO         261250
#
#                               districtName season transmode impExpFlag  \
# 0  MEXICO CROSSINGS THROUGH EAGLE PASS, TX   2019     Truck          I
# 1    MEXICO CROSSINGS THROUGH PROGRESO, TX   2019     Truck          I
# 2    MEXICO CROSSINGS THROUGH PRESIDIO, TX   2019     Truck          I
# 3       MEXICO CROSSINGS THROUGH PHARR, TX   2019     Truck          I
# 4  MEXICO CROSSINGS THROUGH EAGLE PASS, TX   2019     Truck          I
#
#      commodity organic                reportDate  ... Unnamed: 16374  \
# 0  Watermelons   FALSE  2020-07-14T00:00:00.000Z  ...            NaN
# 1  Watermelons   FALSE  2020-07-14T00:00:00.000Z  ...            NaN
# 2  Watermelons   FALSE  2020-07-14T00:00:00.000Z  ...            NaN
# 3  Watermelons   FALSE  2020-07-14T00:00:00.000Z  ...            NaN
# 4  Watermelons   FALSE  2020-07-13T00:00:00.000Z  ...            NaN
#
#   Unnamed: 16375 Unnamed: 16376 Unnamed: 16377 Unnamed: 16378 Unnamed: 16379  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#   Unnamed: 16380 Unnamed: 16381 Unnamed: 16382 Unnamed: 16383
# 0            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN
#
# [5 rows x 16384 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Columns: 16384 entries, _id to Unnamed: 16383
# dtypes: object(16384)
# memory usage: 1.9+ MB

# %%
df.columns
# Out:
# Index(['_id', 'originName', 'totalWeightSum', 'districtName', 'season',
#        'transmode', 'impExpFlag', 'commodity', 'organic', 'reportDate',
#        ...
#        'Unnamed: 16374', 'Unnamed: 16375', 'Unnamed: 16376', 'Unnamed: 16377',
#        'Unnamed: 16378', 'Unnamed: 16379', 'Unnamed: 16380', 'Unnamed: 16381',
#        'Unnamed: 16382', 'Unnamed: 16383'],
#       dtype='object', length=16384)

# %%
df.describe()
# Out:
#             _id originName totalWeightSum  \
# count        15         15             15
# unique       15          2             15
# top     Column1     MEXICO        Column3
# freq          1         14              1
#
#                                    districtName season transmode impExpFlag  \
# count                                        15     15        15         15
# unique                                        7      2         2          2
# top     MEXICO CROSSINGS THROUGH EAGLE PASS, TX   2019     Truck          I
# freq                                          3     14        14         14
#
#           commodity organic                reportDate  ... Unnamed: 16364  \
# count            15      15                        15  ...              1
# unique            3       3                         7  ...              1
# top     Watermelons   FALSE  2020-07-11T00:00:00.000Z  ...    Column16365
# freq             13      13                         4  ...              1
#
#        Unnamed: 16365 Unnamed: 16366 Unnamed: 16367 Unnamed: 16368  \
# count               1              1              1              1
# unique              1              1              1              1
# top       Column16366    Column16367    Column16368    Column16369
# freq                1              1              1              1
#
#        Unnamed: 16369 Unnamed: 16370 Unnamed: 16371 Unnamed: 16372  \
# count               1              1              1              1
# unique              1              1              1              1
# top       Column16370    Column16371    Column16372    Column16373
# freq                1              1              1              1
#
#        Unnamed: 16373
# count               1
# unique              1
# top       Column16374
# freq                1
#
# [4 rows x 16374 columns]

# %%
df.head()
# Out:
#                                     _id originName totalWeightSum  \
# 0  ObjectId("5f0fcf208b390b44eccabe6f")     MEXICO         216436
# 1  ObjectId("5f0fcf208b390b44eccabe6e")     MEXICO         506022
# 2  ObjectId("5f0fcf208b390b44eccabe6d")     MEXICO          40139
# 3  ObjectId("5f0fcf208b390b44eccabe6c")     MEXICO          92059
# 4  ObjectId("5f0fcf1e8b390b44eccabc26")     MEXICO         261250
#
#                               districtName season transmode impExpFlag  \
# 0  MEXICO CROSSINGS THROUGH EAGLE PASS, TX   2019     Truck          I
# 1    MEXICO CROSSINGS THROUGH PROGRESO, TX   2019     Truck          I
# 2    MEXICO CROSSINGS THROUGH PRESIDIO, TX   2019     Truck          I
# 3       MEXICO CROSSINGS THROUGH PHARR, TX   2019     Truck          I
# 4  MEXICO CROSSINGS THROUGH EAGLE PASS, TX   2019     Truck          I
#
#      commodity organic                reportDate  ... Unnamed: 16364  \
# 0  Watermelons   FALSE  2020-07-14T00:00:00.000Z  ...            NaN
# 1  Watermelons   FALSE  2020-07-14T00:00:00.000Z  ...            NaN
# 2  Watermelons   FALSE  2020-07-14T00:00:00.000Z  ...            NaN
# 3  Watermelons   FALSE  2020-07-14T00:00:00.000Z  ...            NaN
# 4  Watermelons   FALSE  2020-07-13T00:00:00.000Z  ...            NaN
#
#   Unnamed: 16365 Unnamed: 16366 Unnamed: 16367 Unnamed: 16368 Unnamed: 16369  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#   Unnamed: 16370 Unnamed: 16371 Unnamed: 16372 Unnamed: 16373
# 0            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN
#
# [5 rows x 16374 columns]
